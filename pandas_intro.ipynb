# %%
import pandas as pd
from pathlib import Path

csv_data_path = Path("pandas-master\\pokemon_data.csv")
csv_data_path
# Out:
# WindowsPath('pandas-master/pokemon_data.csv')

# %% [markdown]
# # Basics

# %%
df = pd.read_csv(csv_data_path)

# %%
df.head(n=5) # df.tail()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# reading headers
for i in df.columns[2:-2]:
    print(i)
# Out:
# Type 1
# Type 2
# HP
# Attack
# Defense
# Sp. Atk
# Sp. Def
# Speed

# %%
# read each column
df['Name'][:5]

# df.Name
df[['Name', 'HP', 'Type 1']][:5]
# Out:
#                     Name  HP Type 1
# 0              Bulbasaur  45  Grass
# 1                Ivysaur  60  Grass
# 2               Venusaur  80  Grass
# 3  VenusaurMega Venusaur  80  Grass
# 4             Charmander  39   Fire

# %%
# read each row
df.iloc[3] # interger location

# read a specific location (R, C)
df.iloc[2,1]

for index, row in df.iterrows():
    print(index, row[['Name', 'Type 1', 'HP']])
    break

# finding specific info
df.loc[df['Type 1'] == 'Fire']
# Out:
# 0 Name      Bulbasaur
# Type 1        Grass
# HP               45
# Name: 0, dtype: object
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# ...

# %% [markdown]
# # Sorting/Desribing Data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending=[1, 0]) # type to asc, hp to dec
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# add new cols that add all poperties
df['Total_statis'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df = df.drop(columns=['Total_statis'])

df['Total_statis'] = df.iloc[:, 4:-2].sum(axis=1)  # [:rows(all), 4:9 cloums]
                                     # adding horizontally
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total_statis
# 0       65     45           1      False           318
# 1       80     60           1      False           405
# 2      100     80           1      False           525
# 3      120     80           1      False           625
# 4       50     65           1      False           309

# %%
# df2 = df[['Total_statis', 'HP', 'Defense']]

cols = list(df.columns.values) # a list of headers
df2 = df[cols[:4] + [cols[-1]] + cols[4:12]] # rearrangement
# first 4 cols stay same, and followed by total col, and followed by the rest of cols
df2.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total_statis  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison           318  45      49       49
# 1  2                Ivysaur  Grass  Poison           405  60      62       63
# 2  3               Venusaur  Grass  Poison           525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison           625  80     100      123
# 4  4             Charmander   Fire     NaN           309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# saving df
# df.to_csv("Path...\\file.csv", index = False)
# df.to_excel("Path...\\file.xlsx", index = False)
# df.to_csv("Path...\\file.txt", index = False, sep = '\t') # delimiter..

# %% [markdown]
# # Filtering Data

# %%
# df.loc[conditions] # filter the satisfied data of condition
df.loc[~df['Name'].str.contains("Mega")] # ! ~ = not
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
import re
df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)] # flags = re.I ignore case
# screen out fire and grass type in type 1
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)] # ^pi[a-z]* = start with pixxxx, * = zero or more
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 219  204               Pineco       Bug       NaN   50      65       90
# 186  172                Pichu  Electric       NaN   20      40       15
# 30    25              Pikachu  Electric       NaN   35      55       40
# 558  499              Pignite      Fire  Fighting   90      93       55
# 239  221            Piloswine       Ice    Ground  100     100       80
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 20    16               Pidgey    Normal    Flying   40      45       40
# 578  519               Pidove    Normal    Flying   50      55       50
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# ...

# %%
# df.loc[condition, constring(at which column/type or all data)] = changes_to_this_value
# df.loc[df['Type 1'] == 'Fire', 'type 1'] = 'Flamer' # change fire into flammer in the type 1
# df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True # change all fire pokemon as lengendary

# %%
# df2.loc[df2['Total_statis'] > 500, ['Generation', 'Legendary']] = ['TEST Gen', 'TEST L'] # modifier multi value if the condition meets

# %% [markdown]
# # Aggregate Statistics

# %%
df = pd.read_csv(csv_data_path)
avg_df = df.groupby(['Type 1']).mean(numeric_only=True) # if pands > 2.0, this is needed

# %%
avg_df.sort_values(['Type 1'], ascending=True)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %%
# groupby(condition).sum() / mean() / count()

# %%
df.groupby(['Type 1']).size()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# dtype: int64

# %%
df.loc[df['Type 1'] == 'Flying']
# Out:
#        #                     Name  Type 1  Type 2  HP  Attack  Defense  \
# 702  641  TornadusIncarnate Forme  Flying     NaN  79     115       70
# 703  641    TornadusTherian Forme  Flying     NaN  79     100       80
# 790  714                   Noibat  Flying  Dragon  40      30       35
# 791  715                  Noivern  Flying  Dragon  85      70       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 702      125       80    111           5       True
# 703      110       90    121           5       True
# 790       45       40     55           6      False
# 791       97       80    123           6      False

# %%
df['count'] = 1

df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# # Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv(csv_data_path, chunksize=5): # 5 rows passed in time
    results = df.groupby(['Type 1']).count()
    new_df = pd.concat([new_df, results])

# %%
new_df
# Out:
#          # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     1    1    NaN      0  1      1       1       1       1     1
# Grass    4    4    NaN      4  4      4       4       4       4     4
# Fire     4    4    NaN      3  4      4       4       4       4     4
# Water    1    1    NaN      0  1      1       1       1       1     1
# Bug      2    2    NaN      0  2      2       2       2       2     2
# ...     ..  ...    ...    ... ..    ...     ...     ...     ...   ...
# Fairy    1    1    NaN      0  1      1       1       1       1     1
# Flying   2    2    NaN      2  2      2       2       2       2     2
# Fire     1    1    NaN      1  1      1       1       1       1     1
# Psychic  2    2    NaN      2  2      2       2       2       2     2
# Rock     2    2    NaN      2  2      2       2       2       2     2
#
#         Generation Legendary
# Fire             1         1
# Grass            4         4
# Fire             4         4
# ...
